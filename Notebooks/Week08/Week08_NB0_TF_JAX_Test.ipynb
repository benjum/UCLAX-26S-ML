# %% [markdown]
# Try running these cells.
# * You *will* see some warnings, mainly complaints about some plugins and placers being registered
# * You should see the cell with `tf.reduce_sum` produce a `tf.Tensor` output, and the final cell should output a plot
#   * If you don't see these, please let me know.

# %%
# If you run on the JupyterHub, execute this cell.  On the JupyterHub, you 
# can only run on one GPU, even if there are multiple GPUs on the device 
# you connect to. These lines make sure we only try to run on 1 GPU
# If you don't use this, you may run into errors if the code tries to
# consume too many resources

# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# The following are also useful to decrease the level of output not related to code output
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# import warnings
# warnings.filterwarnings("ignore")

# %%
import tensorflow as tf

# %%
print(tf.reduce_sum(tf.random.normal([1000, 1000])))

# %%
print('TensorFlow version:',tf.__version__)

for i in tf.config.list_physical_devices():
    print('Recognized devices:',i)

# %%
import matplotlib.pyplot as plt
import jax.numpy as jnp
from jax import grad, vmap

# %%
fig, ax = plt.subplots()

x = jnp.linspace(-2 * jnp.pi, 2 * jnp.pi, 1000)

y = jnp.cos
d1y = grad(y)
d2y = grad(grad(y))

ax.plot(x, y(x), 'k-', lw=4)
ax.plot(x, vmap(d1y)(x), 'b-')
ax.plot(x, -vmap(d2y)(x), 'w--')
